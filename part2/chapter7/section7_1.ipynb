# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import torchvision.datasets as dset

# %%
mnistdata = dset.MNIST(root='./dataset/mnist_root', download=True)

plt.subplot(131)
plt.imshow(mnistdata[0][0].convert('RGB'))
plt.subplot(132)
plt.imshow(mnistdata[1][0].convert('RGB'))
plt.subplot(133)
plt.imshow(mnistdata[2][0].convert('RGB'))

plt.show()

# %%
fashiondata = dset.FashionMNIST(root='./dataset/fashion_root', download=True)

plt.subplot(131)
plt.imshow(fashiondata[0][0].convert('RGB'))
plt.subplot(132)
plt.imshow(fashiondata[1][0].convert('RGB'))
plt.subplot(133)
plt.imshow(fashiondata[2][0].convert('RGB'))

plt.show()

# %%
emnistdata = dset.EMNIST(root='./dataset/emnist_root', split='balanced', train=True, download=True)

plt.subplot(131)
plt.imshow(emnistdata[0][0].convert('RGB'))
plt.subplot(132)
plt.imshow(emnistdata[1][0].convert('RGB'))
plt.subplot(133)
plt.imshow(emnistdata[2][0].convert('RGB'))

plt.show()

# %%
svhndata = dset.SVHN(root='./dataset/svhn_root', download=True)

plt.subplot(131)
plt.imshow(svhndata[0][0])
plt.subplot(132)
plt.imshow(svhndata[1][0])
plt.subplot(133)
plt.imshow(svhndata[2][0])

plt.show()
# Out:
# Using downloaded and verified file: ./dataset/svhn_root/train_32x32.mat

# %%
cifar10data = dset.CIFAR10(root='./dataset/cifar10_root', download=True)

plt.subplot(131)
plt.imshow(cifar10data[0][0])
plt.subplot(132)
plt.imshow(cifar10data[1][0])
plt.subplot(133)
plt.imshow(cifar10data[2][0])

plt.show()
# Out:
# Files already downloaded and verified

# %%
cifar100data = dset.CIFAR100(root='./dataset/cifar100_root', download=True)

plt.subplot(131)
plt.imshow(cifar100data[0][0])
plt.subplot(132)
plt.imshow(cifar100data[1][0])
plt.subplot(133)
plt.imshow(cifar100data[2][0])

plt.show()
# Out:
# Files already downloaded and verified

# %%
stldata = dset.STL10(root='./dataset/stl10_root', download=True)

plt.subplot(131)
plt.imshow(stldata[0][0])
plt.subplot(132)
plt.imshow(stldata[1][0])
plt.subplot(133)
plt.imshow(stldata[2][0])

plt.show()
# Out:
# Files already downloaded and verified
